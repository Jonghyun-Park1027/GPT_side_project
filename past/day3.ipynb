# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

# %%
# streaming 옵션 켜고 콜백을 통해 모든 문장 및 출력 보기
chat = ChatOpenAI(model_name="gpt-4o-2024-08-06", streaming=True, callbacks=[StreamingStdOutCallbackHandler()])  # temperature 등 옵션도 지정 가능
chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world-class international chef. You create easy to follow recipies for any type of cuisine with easy to find ingredients"),
    ("human", "I want to cook {cuisine} food."),
])
chef_chain = chef_prompt | chat
veg_chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a vegetarian chef specialized on making traditional recipies vegetarian. You find alternative ingredients and explain their preparation. You don't radically modify the recipe. If there is no alternative for a food just say you don't how to replace it."),
    ("human", "{recipe}")
])
veg_chain = veg_chef_prompt | chat
final_chain = {"recipe":chef_chain} | veg_chain

final_chain.invoke({
    "cuisine" : "indian",
    
})
# Out:
# Indian cuisine is vibrant, diverse, and full of flavor. Here's a simple recipe for a classic Indian dish, Chicken Tikka Masala, which is a favorite around the world. The ingredients are easy to find, and the recipe is straightforward.
#
# ### Chicken Tikka Masala
#
# #### Ingredients:
# **For the Chicken Marinade:**
# - 500g boneless chicken breast, cut into bite-sized pieces
# - 1 cup plain yogurt
# - 2 tablespoons lemon juice
# - 2 tablespoons vegetable oil
# - 3 cloves garlic, minced
# - 1 tablespoon grated ginger
# - 1 teaspoon ground cumin
# - 1 teaspoon ground coriander
# - 1 teaspoon garam masala
# - 1 teaspoon paprika
# - 1/2 teaspoon turmeric
# - Salt and pepper to taste
#
# **For the Sauce:**
# - 2 tablespoons vegetable oil
# - 1 large onion, finely chopped
# - 3 cloves garlic, minced
# - 1 tablespoon grated ginger
# - 2 teaspoons ground cumin
# - 2 teaspoons ground coriander
# - 1 teaspoon garam masala
# - 1 teaspoon paprika
# - 1 can (400g) crushed tomatoes
# - 1 cup heavy cream (or coconut milk for a dairy-free option)
# - Salt to taste
# - Fresh cilantro, chopped, for garnish
#
# #### Instructions:
#
# 1. **Marinate the Chicken:**
#    - In a large bowl, combine yogurt, lemon juice, oil, garlic, ginger, cumin, coriander, garam masala, paprika, turmeric, salt, and pepper.
#    - Add the chicken pieces and mix until they are well coated.
#    - Cover and refrigerate for at least 1 hour, preferably overnight for deeper flavor.
#
# 2. **Cook the Chicken:**
#    - Preheat your oven to 200°C (400°F).
#    - Thread the marinated chicken pieces onto skewers and place them on a baking sheet.
#    - Bake in the preheated oven for about 15-20 minutes, or until the chicken is cooked through and slightly charred. Alternatively, you can grill the chicken on a barbecue or stovetop grill pan.
#
# 3. **Prepare the Sauce:**
#    - In a large pan, heat the oil over medium heat.
#    - Add the chopped onion and sauté until golden brown.
#    - Stir in the garlic and ginger, and cook for 1-2 minutes until fragrant.
#    - Add cumin, coriander, garam masala, and paprika. Stir well and cook for another minute.
#    - Pour in the crushed tomatoes and bring the mixture to a simmer. Cook for about 10 minutes until the sauce thickens.
#    - Stir in the cream and season with salt. Simmer for an additional 5 minutes.
#
# 4. **Combine and Serve:**
#    - Add the cooked chicken pieces to the sauce and stir to coat the chicken well.
#    - Simmer for another 5 minutes to allow the flavors to meld.
#    - Garnish with chopped cilantro before serving.
#
# 5. **Serve With:**
#    - Serve hot with basmati rice or naan bread. Enjoy!
#
# This recipe is a delicious introduction to Indian cuisine and is sure to impress. Enjoy your cooking adventure!To transform Chicken Tikka Masala into a vegetarian-friendly dish, we can substitute the chicken with a vegetable or plant-based protein that can hold the marinade well and offer a satisfying texture. Here’s how you can make this classic dish vegetarian:
#
# ### Vegetarian Tikka Masala
#
# #### Ingredients:
# **For the Marinade:**
# - 500g paneer (Indian cottage cheese), firm tofu, or cauliflower florets, cut into bite-sized pieces
# - 1 cup plain yogurt (or dairy-free yogurt for a vegan option)
# - 2 tablespoons lemon juice
# - 2 tablespoons vegetable oil
# - 3 cloves garlic, minced
# - 1 tablespoon grated ginger
# - 1 teaspoon ground cumin
# - 1 teaspoon ground coriander
# - 1 teaspoon garam masala
# - 1 teaspoon paprika
# - 1/2 teaspoon turmeric
# - Salt and pepper to taste
#
# **For the Sauce:**
# - 2 tablespoons vegetable oil
# - 1 large onion, finely chopped
# - 3 cloves garlic, minced
# - 1 tablespoon grated ginger
# - 2 teaspoons ground cumin
# - 2 teaspoons ground coriander
# - 1 teaspoon garam masala
# - 1 teaspoon paprika
# - 1 can (400g) crushed tomatoes
# - 1 cup heavy cream or coconut milk (for a dairy-free option)
# - Salt to taste
# - Fresh cilantro, chopped, for garnish
#
# #### Instructions:
#
# 1. **Marinate the Vegetables/Paneer:**
#    - In a large bowl, combine yogurt, lemon juice, oil, garlic, ginger, cumin, coriander, garam masala, paprika, turmeric, salt, and pepper.
#    - Add the paneer, tofu, or cauliflower pieces and mix until they are well coated.
#    - Cover and refrigerate for at least 1 hour, preferably overnight for deeper flavor.
#
# 2. **Cook the Vegetables/Paneer:**
#    - Preheat your oven to 200°C (400°F).
#    - Thread the marinated pieces onto skewers (if using paneer or tofu) and place them on a baking sheet. If using cauliflower, spread them evenly on the sheet.
#    - Bake in the preheated oven for about 15-20 minutes, or until they are cooked through and slightly charred. Alternatively, you can grill them on a barbecue or stovetop grill pan.
#
# 3. **Prepare the Sauce:**
#    - In a large pan, heat the oil over medium heat.
#    - Add the chopped onion and sauté until golden brown.
#    - Stir in the garlic and ginger, and cook for 1-2 minutes until fragrant.
#    - Add cumin, coriander, garam masala, and paprika. Stir well and cook for another minute.
#    - Pour in the crushed tomatoes and bring the mixture to a simmer. Cook for about 10 minutes until the sauce thickens.
#    - Stir in the cream or coconut milk and season with salt. Simmer for an additional 5 minutes.
#
# 4. **Combine and Serve:**
#    - Add the cooked paneer, tofu, or cauliflower to the sauce and stir to coat well.
#    - Simmer for another 5 minutes to allow the flavors to meld.
#    - Garnish with chopped cilantro before serving.
#
# 5. **Serve With:**
#    - Serve hot with basmati rice or naan bread. Enjoy!
#
